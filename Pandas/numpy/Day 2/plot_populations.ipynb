# %%
# %matplotlib inline

# %% [markdown]
# Population exercise
# ===================
#
# Plot populations of hares, lynxes, and carrots

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt')
year, hares, lynxes, carrots = data.T

plt.axes([0.2, 0.1, 0.5, 0.8])
plt.plot(year, hares, year, lynxes, year, carrots)
plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05, 0.5))
plt.show()

# %% [markdown]
# Computes and print, based on the data in populations.txt…
#
# - The mean and std of the populations of each species for the years in the period.
# - Which year each species had the largest population.
# - Which species has the largest population for each year. (Hint: argsort & fancy indexing of np.array(['H', 'L', 'C']))
# - Which years any of the populations is above 50000. (Hint: comparisons and np.any)
# - The top 2 years for each species when they had the lowest populations. (Hint: argsort, fancy indexing)
# - Compare (plot) the change in hare population (see help(np.gradient)) and the number of lynxes. Check correlation (see help(np.corrcoef)).

# %%
# The mean and std of the populations of each species for the years in the period.

populations = data[:,1:]

print("Species:     Hares         Lynxes         Carrots")
print("Mean:", populations.mean(axis=0))
print("Std: ", populations.std(axis=0))
# Out:
# Species:     Hares         Lynxes         Carrots
# Mean: [34080.95238095 20166.66666667 42400.        ]
# Std:  [20897.90645809 16254.59153691  3322.50622558]

# %%
# Which year each species had the largest population.

highest_population = np.argmax(populations, axis=0)
print("                         Hares,Lynxes,Carrots")
print("Highest Population year:", year[highest_population])
# Out:
#                          Hares,Lynxes,Carrots
# Highest Population year: [1903. 1904. 1900.]

# %%
# Which species has the largest population for each year. (Hint: argsort & fancy indexing of np.array(['H', 'L', 'C']))

largest_population_species = np.argmax(populations, axis=1)
species = np.array(['Hare', 'Lynx', 'Carrot'])
print ("Largest population species:")
print([(int(x),y) for x,y in zip(year, species[largest_population_species])])
# print (year )
# print (species[largest_population_species])
# Out:
# Largest population species:
# [(1900, 'Carrot'), (1901, 'Carrot'), (1902, 'Hare'), (1903, 'Hare'), (1904, 'Lynx'), (1905, 'Lynx'), (1906, 'Carrot'), (1907, 'Carrot'), (1908, 'Carrot'), (1909, 'Carrot'), (1910, 'Carrot'), (1911, 'Carrot'), (1912, 'Hare'), (1913, 'Hare'), (1914, 'Hare'), (1915, 'Lynx'), (1916, 'Carrot'), (1917, 'Carrot'), (1918, 'Carrot'), (1919, 'Carrot'), (1920, 'Carrot')]

# %%
# Which years any of the populations is above 50000. (Hint: comparisons and np.any)

above_50000 = np.any(populations > 50000, axis=1)
print ("Year in which any of the populations above 50000:", year[above_50000])
# Out:
# Year in which any of the populations above 50000: [1902. 1903. 1904. 1912. 1913. 1914. 1915.]

# %%
# The top 2 years for each species when they had the lowest populations. (Hint: argsort, fancy indexing)

top_2_years = np.argsort(populations, axis=0)[:2]
print ("Top 2 years for each species when they had the lowest populations:")
print (year[top_2_years])
# Out:
# Top 2 years for each species when they had the lowest populations:
# [[1917. 1900. 1916.]
#  [1916. 1901. 1903.]]

# %%
# Compare (plot) the change in hare population (see help(np.gradient)) and the number of lynxes. Check correlation (see help(np.corrcoef)).

hare_grad = np.gradient(hares)
print ("(Difference in Hares population) vs. Lynxes. correlation", np.corrcoef(hare_grad, lynxes)[0,1])

import matplotlib.pyplot as plt
plt.plot(year, hare_grad, year, -lynxes)
plt.savefig('plot.png')
# Out:
# (Difference in Hares population) vs. Lynxes. correlation -0.9179248480315338
